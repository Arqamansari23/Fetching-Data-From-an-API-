# %% [markdown]
# TMDB API : https://developers.themoviedb.org/
#
# RapidAPI : https://rapidapi.com/collection/list-...
#
# JSON Viewer: http://jsonviewer.stack.hu/

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# # Generate response to  get the API

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')  
# the api_key  can be found in settings of websites

# %%
response   # response 200 means response is succesfull
# Out:
# <Response [200]>

# %%
response.json()  # the respond found in JSOn format
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 123.054,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 18466},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response.json()['results']   # we want only results in the API
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 123.054,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18466},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %% [markdown]
# # Creating DataFrame

# %%
temp_df = pd.DataFrame(response.json()['results'])

# %%
temp_df
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 1   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 2   False  /oo4PVK6AyLZN49BokxDFGyclN86.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg   [35, 18, 10749]   19404
# 5   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg   [16, 10751, 14]     129
# 6   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 7   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 10  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %% [markdown]
# # Getting All the data in Diffrent pages  in API

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):  # total Number of Pages  are 429 
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_9456\3338488543.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\DC\AppData\Local\Temp\ipykernel_9456\3338488543.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\DC\AppData\Local\Temp\ipykernel_9456\3338488543.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\DC\AppData\Local\Temp\ipykernel_9456\3338488543.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df  # All the movies are appended into data frame
# Out:
#       adult                     backdrop_path           genre_ids      id  \
# 0     False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg            [18, 80]     238
# 1     False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg            [18, 80]     278
# 2     False  /oo4PVK6AyLZN49BokxDFGyclN86.jpg            [18, 80]     240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg     [18, 36, 10752]     424
# 4     False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg     [35, 18, 10749]   19404
# ...     ...                               ...                 ...     ...
# 8555  False  /xENKhotB6aYBlnDH2lE0m2y22v1.jpg      [27, 9648, 53]  565028
# 8556  False   /vpUUznNzW85xo02H16RaSxRNS1.jpg  [27, 18, 9648, 53]  539181
# 8557  False  /4xGuNyCX46pwEpdQISRYiaBXEN7.jpg            [80, 53]   64689
# 8558  False  /uQVXQ7VI0jbLDo5QwGGyLQUd1so.jpg       [35, 878, 28]    9397
# 8559  False  /iOt8AODOympcKhRTUdbMomoTREi.jpg       [28, 878, 53]    1738
#
#      original_language                original_title  \
# ...
